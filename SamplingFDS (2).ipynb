# %%
import numpy as np
import pandas as pd

np.random.seed(42)

data = pd.read_csv('/content/median_fillna.csv.xls')
data

real_mean = round(df['co2'].mean(),3)
print(real_mean)
df
# Out:
# 595.803
#       Unnamed: 0  Unnamed: 0.1 iso_code      country  year     co2  \
# 0              0            52      AFG  Afghanistan  2001   0.798
# 1            247            53      AFG  Afghanistan  2002   1.052
# 2            494            54      AFG  Afghanistan  2003   1.186
# 3            741            55      AFG  Afghanistan  2004   0.889
# 4            988            56      AFG  Afghanistan  2005   1.303
# ...          ...           ...      ...          ...   ...     ...
# 4946        3960         25984      ZWE     Zimbabwe  2016  10.738
# 4947        4208         25985      ZWE     Zimbabwe  2017   9.582
# 4948        4456         25986      ZWE     Zimbabwe  2018  11.854
# 4949        4703         25987      ZWE     Zimbabwe  2019  10.949
# 4950        4950         25988      ZWE     Zimbabwe  2020  10.531
#
#       co2_per_capita  trade_co2  cement_co2  cement_co2_per_capita  ...  \
# 0              0.037      2.605       0.007                  0.000  ...
# ...

# %%
simple_random_sample = df.sample(n=4).sort_values(by='iso_code')
simple_random_mean = round(simple_random_sample['co2'].mean(),3)
print(simple_random_mean)
simple_random_sample
# Out:
# 6.785
#       Unnamed: 0  Unnamed: 0.1 iso_code    country  year     co2  \
# 230         2484          1043      ABW      Aruba  2011   2.499
# 1371        3285          6873      EST    Estonia  2014  18.885
# 1957        4800         10413      HTI      Haiti  2020   2.920
# 3464        3390         18084      PSE  Palestine  2014   2.836
#
#       co2_per_capita  trade_co2  cement_co2  cement_co2_per_capita  ...  \
# 230           24.486      2.605       1.341                  0.118  ...
# 1371          14.348     -0.849       0.422                  0.320  ...
# 1957           0.256      2.605       0.078                  0.007  ...
# 3464           0.640      2.605       1.341                  0.118  ...
#
#       ghg_excluding_lucf_per_capita  methane  methane_per_capita  \
# 230                           4.632    8.585               1.013
# 1371                         15.605    1.130               0.858
# 1957                          4.632    8.585               1.013
# ...

# %%
def systematic_sampling(data, step):
    
    indexes = np.arange(0,len(data),step=step)
    systematic_sample = data.iloc[indexes]
    return systematic_sample
    
systematic_sample = systematic_sampling(data, 3)

systematic_mean = round(systematic_sample['co2'].mean(),3)

systematic_sample
# Out:
#       Unnamed: 0  Unnamed: 0.1 iso_code      country  year     co2  \
# 0              0            52      AFG  Afghanistan  2001   0.798
# 3            741            55      AFG  Afghanistan  2004   0.889
# 6           1482            58      AFG  Afghanistan  2007   2.269
# 9           2225            61      AFG  Afghanistan  2010   8.398
# 12          2969            64      AFG  Afghanistan  2013   8.441
# ...          ...           ...      ...          ...   ...     ...
# 4938        1976         25976      ZWE     Zimbabwe  2008   7.720
# 4941        2720         25979      ZWE     Zimbabwe  2011   9.744
# 4944        3464         25982      ZWE     Zimbabwe  2014  11.906
# 4947        4208         25985      ZWE     Zimbabwe  2017   9.582
# 4950        4950         25988      ZWE     Zimbabwe  2020  10.531
#
#       co2_per_capita  trade_co2  cement_co2  cement_co2_per_capita  ...  \
# 0              0.037      2.605       0.007                  0.000  ...
# ...

# %%
outcomes = {'sample_mean':[simple_random_mean,systematic_mean],
           'real_mean':real_mean}


outcomes = pd.DataFrame(outcomes, index=['Simple Random Sampling','Systematic Sampling'])

outcomes['abs_error'] = abs(outcomes['real_mean'] - outcomes['sample_mean'])

outcomes.sort_values(by='abs_error')
# Out:
#                         sample_mean  real_mean  abs_error
# Systematic Sampling         600.551    595.803      4.748
# Simple Random Sampling        6.785    595.803    589.018
